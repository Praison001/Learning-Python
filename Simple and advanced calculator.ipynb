# %%
'''**CALCULATOR Assignment

Contruct a simple and advanced calculator-
As a developer , the user should be able to choose between a simple or advance calculator.
Based on his/her choice, he/she should be able to see the different functionalities offered to him by either simple/advance calc.
Based on his/her choice-entry; your program should compute the desired result back to the user.  
--> simple calc must contain minimum 7 functionalites 
--> advance calc must contain minimum 7 functionalities 

** Use OOPS concept->your script should contain 2 classes 
** Upto you to use inheritence property 
** HINT-import math '''

# %%
import math   #importing a few modules
import cmath
import random

class SimpleCalculator:    #creating a class for simple calculator with the various functions
    def addition(self):
        return 'Answer: {}'.format(a+b)
    def subtraction(self):
        return 'Answer: {}'.format(a-b)
    def multiplication(self):
        return 'Answer: {}'.format(a*b)
    def division(self):
        return 'Answer: {}'.format(a/b)
    def exponentiation(self):
        return 'Answer: {}'.format(a**b)
    def remainder(self):
        return 'Answer: {}'.format(a%b)
    def random(self):
        return 'Answer: {}'.format(random.randrange(a,b))
    
class AdvancedCalculator():          #creating a class for advanced calculator with the various functions
    def base10_logarithm(self):
        return 'Answer: {}'.format(math.log10(c))
    def sin(self):
        return 'Answer: {}'.format(math.sin(c))
    def cos(self):
        return 'Answer: {}'.format(math.cos(c))
    def tan(self):
        return 'Answer: {}'.format(math.tan(c))
    def asin(self):
        return 'Answer: {}'.format(cmath.asin(c))
    def acos(self):
        return 'Answer: {}'.format(cmath.acos(c))
    def atan(self):
        return 'Answer: {}'.format(cmath.atan(c))

    
cal=['1.Simple Calculator','2.Advanced calculator']  #getting the input from the user on which calculator he/she wants  
for x in cal:
    print(x)
cal_in=int(input("Which calculator do you wish to choose? "))


if cal_in==1:
    a=float(input("Enter the first number: "))  #getting two numbers from the user
    b=float(input("Enter the second number: "))
    
    cs=SimpleCalculator()
    #displaying the functions available
    functions_simple=['1.Sum','2.Difference','3.Product','4.Division','5.Exponentian','6.Remainder','7.Random value between the numbers']
    
    for y in functions_simple:
        print(y)
    #getting the input to know which function should be done
    function_in=int(input("Choose which function you wanna perform with the 2 numbers: ")) 
    
    if function_in==1:          #depending on the input, the particular function inside the simple calculator class is called
        print(cs.addition())         
    elif function_in==2:
        print(cs.subtraction())
    elif function_in==3:
        print(cs.multiplication())
    elif function_in==4:
        print(cs.division())
    elif function_in==5:
        print(cs.exponentiation())
    elif function_in==6:
        print(cs.remainder())
    elif function_in==7:
        print(cs.random())
    else:
        print('Please input the correct number...')

elif cal_in==2:
    c=int(input("Enter a number: "))   #getting a number from the user
    
    ca=AdvancedCalculator()
    
     #displaying the functions available
    functions_advanced=['1.base10 logarithm(x)','2.sin(x)','3.cos(x)','4.tan(x)','5.asin(x)','6.acos(x)','7.atan(x)']
    
    for z in functions_advanced:
        print(z)
    #getting the input to know which function should be done    
    function_in1=int(input("Choose which function you wanna perform with the number entered: "))
    
    if function_in1==1:     #depending on the input, the particular function inside the advanced calculator class is called
        print(ca.base10_logarithm())
    elif function_in1==2:
        print(ca.sin())
    elif function_in1==3:
        print(ca.cos())
    elif function_in1==4:
        print(ca.tan())
    elif function_in1==5:
        print(ca.asin())
    elif function_in1==6:
        print(ca.acos())
    elif function_in1==7:
        print(ca.atan())
    else:
        print('Please input the correct number...')
 
else:
    print("Sorry, choose between the two..")
# Out:
# 1.Simple Calculator
# 2.Advanced calculator
# Which calculator do you wish to choose? 2
# Enter a number: 17
# 1.base10 logarithm(x)
# 2.sin(x)
# 3.cos(x)
# 4.tan(x)
# 5.asin(x)
# 6.acos(x)
# 7.atan(x)
# Choose which function you wanna perform with the number entered: 7
# Answer: (1.512040504079174+0j)
